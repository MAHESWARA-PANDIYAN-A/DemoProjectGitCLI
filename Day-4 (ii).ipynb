# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

text = "Generative Ai So Powerful"
tokens = tokenizer.tokenize(text)

print(tokens)

ids = tokenizer.convert_tokens_to_ids(tokens)

print(ids)
# Out:
# ['Gene', '##rative', 'Ai', 'So', 'Power', '##ful']
# [9066, 15306, 19294, 1573, 3794, 2365]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Generated AI is powerful"
inputs = tokenizer(text)
tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"])
print(tokens)
# Out:
# ['[CLS]', 'generated', 'ai', 'is', 'powerful', '[SEP]']

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")
text = "Generated AI is powerful"
inputs = tokenizer(text, return_tensors="pt")
outputs = model(**inputs)
print(outputs.last_hidden_state.shape)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# torch.Size([1, 6, 768])

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "AI is amazing"
inputs = tokenizer(text)
print(inputs["input_ids"])
# Out:
# [101, 9932, 2003, 6429, 102]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text1 = "What is AI"
text2 = "AI means Artificial Intelligence"
inputs = tokenizer(text1, text2)
tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"])
print(tokens)
# Out:
# ['[CLS]', 'what', 'is', 'ai', '[SEP]', 'ai', 'means', 'artificial', 'intelligence', '[SEP]']
