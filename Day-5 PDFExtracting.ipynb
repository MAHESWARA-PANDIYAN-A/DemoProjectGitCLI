# %%
pip install langchain pypdf langchain-community langchain-text-splitters langchain-huggingface faiss-cpu

# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

text='''
AI is transforming education.
RAG helps reduce hallucination in LLMs.
Embeddings convert text into vectors.
'''

splitter = CharacterTextSplitter(
    chunk_size=30,
    chunk_overlap=2
)

chunks = splitter.split_text(text)
print(chunks)
# Out:
# ['AI is transforming education.\nRAG helps reduce hallucination in LLMs.\nEmbeddings convert text into vectors.']

# %%
! pip install langchain
! pip install langchain-community langchain-huggingface
! pip install langchain-text-splitters langchain-community

# %%
from langchain_community.vectorstores import FAISS
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings()

db = FAISS.from_texts(
    chunks,
    embedding_model
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
results = db.similarity_search(
    "What is Clustering?"
)

print(results[0].page_content)
# Out:
# AI is transforming education.
# RAG helps reduce hallucination in LLMs.
# Embeddings convert text into vectors.

# %%
from langchain_community.document_loaders import PyPDFLoader
pdf_path = "/content/rag_test_document.pdf" # <<< PLEASE REPLACE THIS WITH YOUR PDF FILE PATH
loader = PyPDFLoader(pdf_path)
documents = loader.load()
documents
# Out:
# [Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/content/rag_test_document.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Technical Operations Manual: Project\nAethelgard\nDocument Ref: TD-9928-X | Classification: Confidential (Test Data)\n1. System Architecture\nThe Aethelgard system operates on a decentralized mesh network designed to withstand\nlocalized electromagnetic interference. The core processing unit, the Nexus-9 Core, utilizes a\nunique cooling signature to avoid detection by thermal imaging. Unlike standard silicon-\nbased processors, the Nexus-9 employs a gallium-nitride substrate.\nKey Concept: The efficiency of the heat dissipation is calculated using the\nformula η = (Th - Tc) / Th, where Th is the core temperature and Tc is the ambient\ncoolant temperature. \n2. Operational Specifications\nComponent Identifier Standard ValueCritical Threshold\nPrimary CapacitorCAP-77-Alpha450 mF > 525 mF\nSi
# ...
